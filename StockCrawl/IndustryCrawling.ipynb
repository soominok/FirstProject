# %%
import pymysql

# %%
mydb = pymysql.connect(host='localhost', port=3306, user='bitai', 
                       password='456123', db='projdb', 
                       charset= 'utf8')

# %%
mycursor = mydb.cursor(pymysql.cursors.DictCursor)
mycursor.execute("CREATE TABLE rank_crawl(rank int, company VARCHAR(255),
                diff int, face_value VARCHAR(50), market_cap int)")

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install BeautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
urlrank = "https://finance.naver.com/sise/sise_market_sum.nhn?sosok=0&page="

for page in range(1, 2):
    res = requests.get(urlrank + str(page))
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml")
    
    data_rows = soup.find("table", attrs={"class":"type_2"}).find("tbody").find_all("tr")
    for row in data_rows:
        columns = row.find_all("td")
        if len(columns) <= 1: #의미 없는 데이터는 skip
            continue
        data = [column.get_text().strip() for column in columns]
        print(data)
# Out:
# ['1', '삼성전자', '56,000', '400', '+0.72%', '100', '3,343,078', '5,969,783', '56.02', '6,935,545', '17.52', '8.69', '']
# ['2', 'SK하이닉스', '78,300', '800', '-1.01%', '5,000', '570,026', '728,002', '47.47', '1,492,086', '24.94', '4.25', '']
# ['3', 'NAVER', '335,500', '1,500', '-0.45%', '100', '551,104', '164,263', '55.55', '635,701', '78.21', '10.56', '']
# ['4', 'LG화학', '763,000', '1,000', '+0.13%', '5,000', '538,620', '70,592', '36.53', '306,778', '131.53', '1.84', '']
# ['5', '삼성바이오로직스', '802,000', '1,000', '+0.12%', '2,500', '530,643', '66,165', '10.33', '48,267', '154.50', '4.77', '']
# ['6', '셀트리온', '306,000', '1,500', '+0.49%', '1,000', '413,081', '134,994', '21.56', '326,689', '103.20', '11.19', '']
# ['7', '삼성전자우', '48,600', '200', '+0.41%', '100', '399,923', '822,887', '88.06', '695,885', '15.21', 'N/A', '']
# ['8', '현대차', '173,500', '10,000', '+6.12%', '5,000', '370,714', '213,668', '32.05', '3,992,236', '25.00', '4.32', '']
# ...

# %%
# Out:
# /home/bitai/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:389: UserWarning: "https://finance.naver.com/sise/sise_market_sum.nhn?sosok=0&page=" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-d51ea66c8348> in <module>
#      15         data = [column.get_text().strip() for column in columns]
#      16         cnt += 1
# ---> 17         print(str(cnt)+". " + row.data)
#      18         if cnt == 20:
#      19             break
#
# TypeError: can only concatenate str (not "NoneType") to str
